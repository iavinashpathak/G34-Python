# %%
import pandas as pd

# %%
index = 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'

# %%
col1 = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %%
df = pd.DataFrame(col1, columns=['col1'], index=index)
df
# Out:
#    col1
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# i    90

# %%
df.loc['a':'d', 'col1']
# Out:
# a    10
# b    20
# c    30
# d    40
# Name: col1, dtype: int64

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
X = data.data
y = data.target
cols = data.feature_names

# %%
df2 = pd.DataFrame(X, columns=cols)

# %%
df2['target'] = y

# %%
df2.sample(10)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 26                 5.0               3.4                1.6               0.4
# 32                 5.2               4.1                1.5               0.1
# 21                 5.1               3.7                1.5               0.4
# 63                 6.1               2.9                4.7               1.4
# 71                 6.1               2.8                4.0               1.3
# 61                 5.9               3.0                4.2               1.5
# 81                 5.5               2.4                3.7               1.0
# 128                6.4               2.8                5.6               2.1
# 118                7.7               2.6                6.9               2.3
# 127                6.1               3.0                4.9               1.8
#
#      target
# 26        0
# 32        0
# 21        0
# 63        1
# 71        1
# 61        1
# 81        1
# ...

# %%
df2['index'] = [str(item) for item in range(150)]

# %%
index = pd.Series([str(item) for item in range(150, 0, -1)])

# %%
df2.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target index
# 145       2   145
# 146       2   146
# 147       2   147
# 148       2   148
# 149       2   149

# %%
df2.set_index(index)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 150                5.1               3.5                1.4               0.2
# 149                4.9               3.0                1.4               0.2
# 148                4.7               3.2                1.3               0.2
# 147                4.6               3.1                1.5               0.2
# 146                5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 5                  6.7               3.0                5.2               2.3
# 4                  6.3               2.5                5.0               1.9
# 3                  6.5               3.0                5.2               2.0
# 2                  6.2               3.4                5.4               2.3
# 1                  5.9               3.0                5.1               1.8
#
#      target index
# ...
