# %% [markdown]
# # <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# ## Use the file company_sales_data.csv

# %%
import numpy as np
import pandas as pd

from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/SUNIL/Desktop/G34-Python/Practical/25-04 Assignment_Introduction_to_Data_Visualization/company_sales_data.csv')
df.sample(5)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 5              6       2760      1555        4890         7490     1890
# 1              2       2630      1200        5100         6100     2100
# 0              1       2500      1500        5200         9200     1200
# 8              9       3540      1780        6100         8100     2100
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 5          1555        20140        201400
# 1          1200        18330        183300
# 0          1500        21100        211000
# 8          1780        23400        234000
# 11         1760        30020        300200

# %%
df['new_col'] = 'ajka'
df
df.sum(axis=1, numeric_only=True)
# Out:
# 0     253201
# 1     219962
# 2     269643
# 3     267244
# 4     251525
# 5     241686
# 6     345817
# 7     422728
# 8     280809
# 9     320050
# 10    483631
# 11    360252
# dtype: int64

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### Plot the total profit across the months
#
# * X label name = Month Number
# * Y label name = Total profit

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
# Your code here
plt.plot(df['month_number'], df['total_profit'], 'r')
plt.plot(df['month_number'], df['total_profit'], 'ro')
plt.title('Monthly Profit of company')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.show()

# %% [markdown]
# # <b><u>Problem 2 </u></b>
#
# ### Read face cream and facewash product sales data and show it using the bar chart. The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %% [markdown]
# ### Expected output:
# ![image.png](attachment:image.png)

# %%
# Your code here
sales_by_month = df[['month_number', 'facewash', 'facecream']]
sales_by_month = sales_by_month.set_index('month_number')

sales_by_month.plot.bar()
plt.show()

# %%
# !pip install openpyxl

# %% [markdown]
# # <b><u>Problem 3</u></b>
#
# ### Display the number of units sold per month for each product using multiline plots. (i.e. separate plotline for each product ).

# %% [markdown]
# ### Expected Output:
# ![image.png](attachment:image.png)

# %%
# Your code here
