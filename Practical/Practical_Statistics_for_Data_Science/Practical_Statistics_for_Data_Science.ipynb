# %% [markdown]
# # **Practical Statistics for Data Science & Machine Learning**
#
# Welcome to this course on Practical Statistics! By the end of these modules, you'll have a solid understanding of the statistical concepts most commonly used in Data Science and Machine Learning, and the ability to implement them in Python.
#
# ---
# ## Table of Contents
# - [Module 1: Introduction to Statistics & Data Exploration](#module-1)
# - [Module 2: Data Visualization & Distributions](#module-2)
# - [Module 3: Probability & Sampling](#module-3)
# - [Module 4: Hypothesis Testing & Statistical Inference](#module-4)
# - [Module 5: Correlation, Regression & Feature Relationships](#module-5)
#
# ---

# %% [markdown]
# <h2><span style="color:red">🚨 Run the below cell to install required packages and start the timer</span></h2>

# %%
# Run this cell to install all required libraries for this course notebook

# !pip install numpy pandas matplotlib seaborn scikit-learn scipy statstest-1.0.0-py3-none-any.whl ipywidgets
import time
import threading
import ipywidgets as widgets
from IPython.display import display

timer_out = widgets.Output()
display(timer_out)

def countdown_timer(total_seconds=3600):
    for remaining in range(total_seconds, 0, -1):
        mins, secs = divmod(remaining, 60)
        timeformat = f"{mins:02d}:{secs:02d} remaining"
        with timer_out:
            timer_out.clear_output(wait=True)
            print(timeformat)
        time.sleep(1)
    with timer_out:
        timer_out.clear_output(wait=True)
        print("⏰⏰⏰ TIME IS UP! Please stop and submit your notebook. ⏰⏰⏰")

if '_timer_started' not in globals():
    _timer_started = True
    timer_thread = threading.Thread(target=countdown_timer, args=(3600,))
    timer_thread.start()
else:
    print("Timer has already been started! Do not run this cell again.")
# Out:
# Processing c:\users\sunil\desktop\g34-python\practical\practical_statistics_for_data_science\statstest-1.0.0-py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\sunil\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\sunil\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\sunil\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\sunil\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\sunil\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: scipy in c:\users\sunil\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: ipywidgets in c:\users\sunil\anaconda3\lib\site-packages (7.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sunil\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sunil\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sunil\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sunil\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\sunil\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sunil\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\sunil\anaconda3\lib\site-packages (from ipywidgets) (1.0.0)
# Requirement already satisfied: decorator in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: colorama in c:\users\sunil\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\sunil\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\sunil\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets) (7.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sunil\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\sunil\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\sunil\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in c:\users\sunil\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\sunil\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\sunil\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.4.2)
# Requirement already satisfied: wcwidth in c:\users\sunil\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets) (0.2.5)
# Requirement already satisfied: executing in c:\users\sunil\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\sunil\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\sunil\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.6.2)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.1.5)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.14)
# Requirement already satisfied: pyzmq>=24 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.29.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.2.0)
# Requirement already satisfied: setuptools>=40.8.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (71.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\sunil\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.32.3)
# Requirement already satisfied: idna>=2.8 in c:\users\sunil\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sunil\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\sunil\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (21.2.0)
# Requirement already satisfied: certifi in c:\users\sunil\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sunil\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sunil\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\sunil\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.8.11)
# Requirement already satisfied: nest-asyncio in c:\users\sunil\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.6.0)
# Requirement already satisfied: psutil in c:\users\sunil\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (5.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sunil\anaconda3\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sunil\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sunil\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sunil\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sunil\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (308)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\sunil\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\sunil\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\sunil\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sunil\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sunil\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.3.0)
# Requirement already satisfied: webencodings in c:\users\sunil\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (0.5.1)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\sunil\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\sunil\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sunil\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.5)
# Requirement already satisfied: pycparser in c:\users\sunil\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\sunil\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets) (1.3.0)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, statstest, fqdn, isoduration
# Successfully installed fqdn-1.5.1 isoduration-20.11.0 statstest-1.0.0 uri-template-1.3.0 webcolors-24.11.1
# Output()
# 59:44 remaining
# 59:43 remaining
# 59:42 remaining
# 59:41 remaining
# 59:40 remaining
# 59:39 remaining
# 59:38 remaining
# 59:37 remaining
# 59:36 remaining
# 59:35 remaining
# 59:34 remaining
# 59:33 remaining
# 59:32 remaining
# 59:31 remaining
# 59:30 remaining
# 59:29 remaining
# 59:28 remaining
# 59:27 remaining
# 59:26 remaining
# 59:25 remaining
# 59:24 remaining
# 59:23 remaining
# 59:22 remaining
# 59:21 remaining
# 59:20 remaining
# 59:19 remaining
# 59:18 remaining
# 59:17 remaining
# 59:16 remaining
# 59:15 remaining
# 59:14 remaining
# 59:13 remaining
# 59:12 remaining
# 59:11 remaining
# 59:10 remaining
# 59:09 remaining
# 59:08 remaining
# 59:07 remaining
# 59:06 remaining
# 59:05 remaining
# 59:04 remaining
# 59:03 remaining
# 59:02 remaining
# 59:01 remaining
# 59:00 remaining
# 58:59 remaining
# 58:58 remaining
# 58:57 remaining
# 58:56 remaining
# 58:55 remaining
# 58:54 remaining
# 58:53 remaining
# 58:52 remaining
# 58:51 remaining
# 58:50 remaining
# 58:49 remaining
# 58:48 remaining
# 58:47 remaining
# 58:46 remaining
# 58:45 remaining
# 58:44 remaining
# 58:43 remaining
# 58:42 remaining
# 58:41 remaining
# 58:40 remaining
# 58:39 remaining
# 58:38 remaining
# 58:37 remaining
# 58:36 remaining
# 58:35 remaining
# 58:34 remaining
# 58:33 remaining
# 58:32 remaining
# 58:31 remaining
# 58:30 remaining
# 58:29 remaining
# 58:28 remaining
# 58:27 remaining
# 58:26 remaining
# 58:25 remaining
# 58:24 remaining
# 58:23 remaining
# 58:22 remaining
# 58:21 remaining
# 58:20 remaining
# 58:19 remaining
# 58:18 remaining
# 58:17 remaining
# 58:16 remaining
# 58:15 remaining
# 58:14 remaining
# 58:13 remaining
# 58:12 remaining
# 58:11 remaining
# 58:10 remaining
# 58:09 remaining
# 58:08 remaining
# 58:07 remaining
# 58:06 remaining
# 58:05 remaining
# 58:04 remaining
# 58:03 remaining
# 58:02 remaining
# 58:01 remaining
# 58:00 remaining
# 57:59 remaining
# 57:58 remaining
# 57:57 remaining
# 57:56 remaining
# 57:55 remaining
# 57:54 remaining
# 57:53 remaining
# 57:52 remaining
# 57:51 remaining
# 57:50 remaining
# 57:49 remaining
# 57:48 remaining
# 57:47 remaining
# 57:46 remaining
# 57:45 remaining
# 57:44 remaining
# 57:43 remaining
# 57:42 remaining
# 57:41 remaining
# 57:40 remaining
# 57:39 remaining
# 57:38 remaining
# 57:37 remaining
# 57:36 remaining
# 57:35 remaining
# 57:34 remaining
# 57:33 remaining
# 57:32 remaining
# 57:31 remaining
# 57:30 remaining
# 57:29 remaining
# 57:28 remaining
# 57:27 remaining
# 57:26 remaining
# 57:25 remaining
# 57:24 remaining
# 57:23 remaining
# 57:22 remaining
# 57:21 remaining
# 57:20 remaining
# 57:19 remaining
# 57:18 remaining
# 57:17 remaining
# 57:16 remaining
# 57:15 remaining
# 57:14 remaining
# 57:13 remaining
# 57:12 remaining
# 57:11 remaining
# 57:10 remaining
# 57:09 remaining
# 57:08 remaining
# 57:07 remaining
# 57:06 remaining
# 57:05 remaining
# 57:04 remaining
# 57:03 remaining
# 57:02 remaining
# 57:01 remaining
# 57:00 remaining
# 56:59 remaining
# 56:58 remaining
# 56:57 remaining
# 56:56 remaining
# 56:55 remaining
# 56:54 remaining
# 56:53 remaining
# 56:52 remaining
# 56:51 remaining
# 56:50 remaining
# 56:49 remaining
# 56:48 remaining
# 56:47 remaining
# 56:46 remaining
# 56:45 remaining
# 56:44 remaining
# 56:43 remaining
# 56:42 remaining
# 56:41 remaining
# 56:40 remaining
# 56:39 remaining
# 56:38 remaining
# 56:37 remaining
# 56:36 remaining
# 56:35 remaining
# 56:34 remaining
# 56:33 remaining
# 56:32 remaining
# 56:31 remaining
# 56:30 remaining
# 56:29 remaining
# 56:28 remaining
# 56:27 remaining
# 56:26 remaining
# 56:25 remaining
# 56:24 remaining
# 56:23 remaining
# 56:22 remaining
# 56:21 remaining
# 56:20 remaining
# 56:19 remaining
# 56:18 remaining
# 56:17 remaining
# 56:16 remaining
# 56:15 remaining
# 56:14 remaining
# 56:13 remaining
# 56:12 remaining
# 56:11 remaining
# 56:10 remaining
# 56:09 remaining
# 56:08 remaining
# 56:07 remaining
# 56:06 remaining
# 56:05 remaining
# 56:04 remaining
# 56:03 remaining
# 56:02 remaining
# 56:01 remaining
# 56:00 remaining
# 55:59 remaining
# 55:58 remaining
# 55:57 remaining
# 55:56 remaining
# 55:55 remaining
# 55:54 remaining
# 55:53 remaining
# 55:52 remaining
# 55:51 remaining
# 55:50 remaining
# 55:49 remaining
# 55:48 remaining
# 55:47 remaining
# 55:46 remaining
# 55:45 remaining
# 55:44 remaining
# 55:43 remaining
# 55:42 remaining
# 55:41 remaining
# 55:40 remaining
# 55:39 remaining
# 55:38 remaining
# 55:37 remaining
# 55:36 remaining
# 55:35 remaining
# 55:34 remaining
# 55:33 remaining
# 55:32 remaining
# 55:31 remaining
# 55:30 remaining
# 55:29 remaining
# 55:28 remaining
# 55:27 remaining
# 55:26 remaining
# 55:25 remaining
# 55:24 remaining
# 55:23 remaining
# 55:22 remaining
# 55:21 remaining
# 55:20 remaining
# 55:19 remaining
# 55:18 remaining
# 55:17 remaining
# 55:16 remaining
# 55:15 remaining
# 55:14 remaining
# 55:13 remaining
# 55:12 remaining
# 55:11 remaining
# 55:10 remaining
# 55:09 remaining
# 55:08 remaining
# 55:07 remaining
# 55:06 remaining
# 55:05 remaining
# 55:04 remaining
# 55:03 remaining
# 55:02 remaining
# 55:01 remaining
# 55:00 remaining
# 54:59 remaining
# 54:58 remaining
# 54:57 remaining
# 54:56 remaining
# 54:55 remaining
# 54:54 remaining
# 54:53 remaining
# 54:52 remaining
# 54:51 remaining
# 54:50 remaining
# 54:49 remaining
# 54:48 remaining
# 54:47 remaining
# 54:46 remaining
# 54:45 remaining
# 54:44 remaining
# 54:43 remaining
# 54:42 remaining
# 54:41 remaining
# 54:40 remaining
# 54:39 remaining
# 54:38 remaining
# 54:37 remaining
# 54:36 remaining
# 54:35 remaining
# 54:34 remaining
# 54:33 remaining
# 54:32 remaining
# 54:31 remaining
# 54:30 remaining
# 54:29 remaining
# 54:28 remaining
# 54:27 remaining
# 54:26 remaining
# 54:25 remaining
# 54:24 remaining
# 54:23 remaining
# 54:22 remaining
# 54:21 remaining
# 54:20 remaining
# 54:19 remaining
# 54:18 remaining
# 54:17 remaining
# 54:16 remaining
# 54:15 remaining
# 54:14 remaining
# 54:13 remaining
# 54:12 remaining
# 54:11 remaining
# 54:10 remaining
# 54:09 remaining
# 54:08 remaining
# 54:07 remaining
# 54:06 remaining
# 54:05 remaining
# 54:04 remaining
# 54:03 remaining
# 54:02 remaining
# 54:01 remaining
# 54:00 remaining
# 53:59 remaining
# 53:58 remaining
# 53:57 remaining
# 53:56 remaining
# 53:55 remaining
# 53:54 remaining
# 53:53 remaining
# 53:52 remaining
# 53:51 remaining
# 53:50 remaining
# 53:49 remaining
# 53:48 remaining
# 53:47 remaining
# 53:46 remaining
# 53:45 remaining
# 53:44 remaining
# 53:43 remaining
# 53:42 remaining
# 53:41 remaining
# 53:40 remaining
# 53:39 remaining
# 53:38 remaining
# 53:37 remaining
# 53:36 remaining
# 53:35 remaining
# 53:34 remaining
# 53:33 remaining
# 53:32 remaining
# 53:31 remaining
# 53:30 remaining
# 53:29 remaining
# 53:28 remaining
# 53:27 remaining
# 53:26 remaining
# 53:25 remaining
# 53:24 remaining
# 53:23 remaining
# 53:22 remaining
# 53:21 remaining
# 53:20 remaining
# 53:19 remaining
# 53:18 remaining
# 53:17 remaining
# 53:16 remaining
# 53:15 remaining
# 53:14 remaining
# 53:13 remaining
# 53:12 remaining
# 53:11 remaining
# 53:10 remaining
# 53:09 remaining
# 53:08 remaining
# 53:07 remaining
# 53:06 remaining
# 53:05 remaining
# 53:04 remaining
# 53:03 remaining
# 53:02 remaining
# 53:01 remaining
# 53:00 remaining
# 52:59 remaining
# 52:58 remaining
# 52:57 remaining
# 52:56 remaining
# 52:55 remaining
# 52:54 remaining
# 52:53 remaining
# 52:52 remaining
# 52:51 remaining
# 52:50 remaining
# 52:49 remaining
# 52:48 remaining
# 52:47 remaining
# 52:46 remaining
# 52:45 remaining
# 52:44 remaining
# 52:43 remaining
# 52:42 remaining
# 52:41 remaining
# 52:40 remaining
# 52:39 remaining
# 52:38 remaining
# 52:37 remaining
# 52:36 remaining
# 52:35 remaining
# 52:34 remaining
# 52:33 remaining
# 52:32 remaining
# 52:31 remaining
# 52:30 remaining
# 52:29 remaining
# 52:28 remaining
# 52:27 remaining
# 52:26 remaining
# 52:25 remaining
# 52:24 remaining
# 52:23 remaining
# 52:22 remaining
# 52:21 remaining
# 52:20 remaining
# 52:19 remaining
# 52:18 remaining
# 52:17 remaining
# 52:16 remaining
# 52:15 remaining
# 52:14 remaining
# 52:13 remaining
# 52:12 remaining
# 52:11 remaining
# 52:10 remaining
# 52:09 remaining
# 52:08 remaining
# 52:07 remaining
# 52:06 remaining
# 52:05 remaining
# 52:04 remaining
# 52:03 remaining
# 52:02 remaining
# 52:01 remaining
# 52:00 remaining
# 51:59 remaining
# 51:58 remaining
# 51:57 remaining
# 51:56 remaining
# 51:55 remaining
# 51:54 remaining
# 51:53 remaining
# 51:52 remaining
# 51:51 remaining
# 51:50 remaining
# 51:49 remaining
# 51:48 remaining
# 51:47 remaining
# 51:46 remaining
# 51:45 remaining
# 51:44 remaining
# 51:43 remaining
# 51:42 remaining
# 51:41 remaining
# 51:40 remaining
# 51:39 remaining
# 51:38 remaining
# 51:37 remaining
# 51:36 remaining
# 51:35 remaining
# 51:34 remaining
# 51:33 remaining
# 51:32 remaining
# 51:31 remaining
# 51:30 remaining
# 51:29 remaining
# 51:28 remaining
# 51:27 remaining
# 51:26 remaining
# 51:25 remaining
# 51:24 remaining
# 51:23 remaining
# 51:22 remaining
# 51:21 remaining
# 51:20 remaining
# 51:19 remaining
# 51:18 remaining
# 51:17 remaining
# 51:16 remaining
# 51:15 remaining
# 51:14 remaining
# 51:13 remaining
# 51:12 remaining
# 51:11 remaining
# 51:10 remaining
# 51:09 remaining
# 51:08 remaining
# 51:07 remaining
# 51:06 remaining
# 51:05 remaining
# 51:04 remaining
# 51:03 remaining
# 51:02 remaining
# 51:01 remaining
# 51:00 remaining
# 50:59 remaining
# 50:58 remaining
# 50:57 remaining
# 50:56 remaining
# 50:55 remaining
# 50:54 remaining
# 50:53 remaining
# 50:52 remaining
# 50:51 remaining
# 50:50 remaining
# 50:49 remaining
# 50:48 remaining
# 50:47 remaining
# 50:46 remaining
# 50:45 remaining
# 50:44 remaining
# 50:43 remaining
# 50:42 remaining
# 50:41 remaining
# 50:40 remaining
# 50:39 remaining
# 50:38 remaining
# 50:37 remaining
# 50:36 remaining
# 50:35 remaining
# 50:34 remaining
# 50:33 remaining
# 50:32 remaining
# 50:31 remaining
# 50:30 remaining
# 50:29 remaining
# 50:28 remaining
# 50:27 remaining
# 50:26 remaining
# 50:25 remaining
# 50:24 remaining
# 50:23 remaining
# 50:22 remaining
# 50:21 remaining
# 50:20 remaining
# 50:19 remaining
# 50:18 remaining
# 50:17 remaining
# 50:16 remaining
# 50:15 remaining
# 50:14 remaining
# 50:13 remaining
# 50:12 remaining
# 50:11 remaining
# 50:10 remaining
# 50:09 remaining
# 50:08 remaining
# 50:07 remaining
# 50:06 remaining
# 50:05 remaining
# 50:04 remaining
# 50:03 remaining
# 50:02 remaining
# 50:01 remaining
# 50:00 remaining
# 49:59 remaining
# 49:58 remaining
# 49:57 remaining
# 49:56 remaining
# 49:55 remaining
# 49:54 remaining
# 49:53 remaining
# 49:52 remaining
# 49:51 remaining
# 49:50 remaining
# 49:49 remaining
# 49:48 remaining
# 49:47 remaining
# 49:46 remaining
# 49:45 remaining
# 49:44 remaining
# 49:43 remaining
# 49:42 remaining
# 49:41 remaining
# 49:40 remaining
# 49:39 remaining
# 49:38 remaining
# 49:37 remaining
# 49:36 remaining
# 49:35 remaining
# 49:34 remaining
# 49:33 remaining
# 49:32 remaining
# 49:31 remaining
# 49:30 remaining
# 49:29 remaining
# 49:28 remaining
# 49:27 remaining
# 49:26 remaining
# 49:25 remaining
# 49:24 remaining
# 49:23 remaining
# 49:22 remaining
# 49:21 remaining
# 49:20 remaining
# 49:19 remaining
# 49:18 remaining
# 49:17 remaining
# 49:16 remaining
# 49:15 remaining
# 49:14 remaining
# 49:13 remaining
# 49:12 remaining
# 49:11 remaining
# 49:10 remaining
# 49:09 remaining
# 49:08 remaining
# 49:07 remaining
# 49:06 remaining
# 49:05 remaining
# 49:04 remaining
# 49:03 remaining
# 49:02 remaining
# 49:01 remaining
# 49:00 remaining
# 48:59 remaining
# 48:58 remaining
# 48:57 remaining
# 48:56 remaining
# 48:55 remaining
# 48:54 remaining
# 48:53 remaining
# 48:52 remaining
# 48:51 remaining
# 48:50 remaining
# 48:49 remaining
# 48:48 remaining
# 48:47 remaining
# 48:46 remaining
# 48:45 remaining
# 48:44 remaining
# 48:43 remaining
# 48:42 remaining
# 48:41 remaining
# 48:40 remaining
# 48:39 remaining
# 48:38 remaining
# 48:37 remaining
# 48:36 remaining
# 48:35 remaining
# 48:34 remaining
# 48:33 remaining
# 48:32 remaining
# 48:31 remaining
# 48:30 remaining
# 48:29 remaining
# 48:28 remaining
# 48:27 remaining
# 48:26 remaining
# 48:25 remaining
# 48:24 remaining
# 48:23 remaining
# 48:22 remaining
# 48:21 remaining
# 48:20 remaining
# 48:19 remaining
# 48:18 remaining
# 48:17 remaining
# 48:16 remaining
# 48:15 remaining
# 48:14 remaining
# 48:13 remaining
# 48:12 remaining
# 48:11 remaining
# 48:10 remaining
# 48:09 remaining
# 48:08 remaining
# 48:07 remaining
# 48:06 remaining
# 48:05 remaining
# 48:04 remaining
# 48:03 remaining
# 48:02 remaining
# 48:01 remaining
# 48:00 remaining
# 47:59 remaining
# 47:58 remaining
# 47:57 remaining
# 47:56 remaining
# 47:55 remaining
# 47:54 remaining
# 47:53 remaining
# 47:52 remaining
# 47:51 remaining
# 47:50 remaining
# 47:49 remaining
# 47:48 remaining
# 47:47 remaining
# 47:46 remaining
# 47:45 remaining
# 47:44 remaining
# 47:43 remaining
# 47:42 remaining
# 47:41 remaining
# 47:40 remaining
# 47:39 remaining
# 47:38 remaining
# 47:37 remaining
# 47:36 remaining
# 47:35 remaining
# 47:34 remaining
# 47:33 remaining
# 47:32 remaining
# 47:31 remaining
# 47:30 remaining
# 47:29 remaining
# 47:28 remaining
# 47:27 remaining
# 47:26 remaining
# 47:25 remaining
# 47:24 remaining
# 47:23 remaining
# 47:22 remaining
# 47:21 remaining
# 47:20 remaining
# 47:19 remaining
# 47:18 remaining
# 47:17 remaining
# 47:16 remaining
# 47:15 remaining
# 47:14 remaining
# 47:13 remaining
# 47:12 remaining
# 47:11 remaining
# 47:10 remaining
# 47:09 remaining
# 47:08 remaining
# 47:07 remaining
# 47:06 remaining
# 47:05 remaining
# 47:04 remaining
# 47:03 remaining
# 47:02 remaining
# 47:01 remaining
# 47:00 remaining
# 46:59 remaining
# 46:58 remaining
# 46:57 remaining
# 46:56 remaining
# 46:55 remaining
# 46:54 remaining
# 46:53 remaining
# 46:52 remaining
# 46:51 remaining
# 46:50 remaining
# 46:49 remaining
# 46:48 remaining
# 46:47 remaining
# 46:46 remaining
# 46:45 remaining
# 46:44 remaining
# 46:43 remaining
# 46:42 remaining
# 46:41 remaining
# 46:40 remaining
# 46:39 remaining
# 46:38 remaining
# 46:37 remaining
# 46:36 remaining
# 46:35 remaining
# 46:34 remaining
# 46:33 remaining
# 46:32 remaining
# 46:31 remaining
# 46:30 remaining
# 46:29 remaining
# 46:28 remaining
# 46:27 remaining
# 46:26 remaining
# 46:25 remaining
# 46:24 remaining
# 46:23 remaining
# 46:22 remaining
# 46:21 remaining
# 46:20 remaining
# 46:19 remaining
# 46:18 remaining
# 46:17 remaining
# 46:16 remaining
# 46:15 remaining
# 46:14 remaining
# 46:13 remaining
# 46:12 remaining
# 46:11 remaining
# 46:10 remaining
# 46:09 remaining
# 46:08 remaining
# 46:07 remaining
# 46:06 remaining
# 46:05 remaining
# 46:04 remaining
# 46:03 remaining
# 46:02 remaining
# 46:01 remaining
# 46:00 remaining
# 45:59 remaining
# 45:58 remaining
# 45:57 remaining
# 45:56 remaining
# 45:55 remaining
# 45:54 remaining
# 45:53 remaining
# 45:52 remaining
# 45:51 remaining
# 45:50 remaining
# 45:49 remaining
# 45:48 remaining
# 45:47 remaining
# 45:46 remaining
# 45:45 remaining
# 45:44 remaining
# 45:43 remaining
# 45:42 remaining
# 45:41 remaining
# 45:40 remaining
# 45:39 remaining
# 45:38 remaining
# 45:37 remaining
# 45:36 remaining
# 45:35 remaining
# 45:34 remaining
# 45:33 remaining
# 45:32 remaining
# 45:31 remaining
# 45:30 remaining
# 45:29 remaining
# 45:28 remaining
# 45:27 remaining
# 45:26 remaining
# 45:25 remaining
# 45:24 remaining
# 45:23 remaining
# 45:22 remaining
# 45:21 remaining
# 45:20 remaining
# 45:19 remaining
# 45:18 remaining
# 45:17 remaining
# 45:16 remaining
# 45:15 remaining
# 45:14 remaining
# 45:13 remaining
# 45:12 remaining
# 45:11 remaining
# 45:10 remaining
# 45:09 remaining
# 45:08 remaining
# 45:07 remaining
# 45:06 remaining
# 45:05 remaining
# 45:04 remaining
# 45:03 remaining
# 45:02 remaining
# 45:01 remaining
# 45:00 remaining
# 44:59 remaining
# 44:58 remaining
# 44:57 remaining
# 44:56 remaining
# 44:55 remaining
# 44:54 remaining
# 44:53 remaining
# 44:52 remaining
# 44:51 remaining
# 44:50 remaining
# 44:49 remaining
# 44:48 remaining
# 44:47 remaining
# 44:46 remaining
# 44:45 remaining
# 44:44 remaining
# 44:43 remaining
# 44:42 remaining
# 44:41 remaining
# 44:40 remaining
# 44:39 remaining
# 44:38 remaining
# 44:37 remaining
# 44:36 remaining
# 44:35 remaining
# 44:34 remaining
# 44:33 remaining
# 44:32 remaining
# 44:31 remaining
# 44:30 remaining
# 44:29 remaining
# 44:28 remaining
# 44:27 remaining
# 44:26 remaining
# 44:25 remaining
# 44:24 remaining
# 44:23 remaining
# 44:22 remaining
# 44:21 remaining
# 44:20 remaining
# 44:19 remaining
# 44:18 remaining
# 44:17 remaining
# 44:16 remaining
# 44:15 remaining
# 44:14 remaining
# 44:13 remaining
# 44:12 remaining
# 44:11 remaining
# 44:10 remaining
# 44:09 remaining
# 44:08 remaining
# 44:07 remaining
# 44:06 remaining
# 44:05 remaining
# 44:04 remaining
# 44:03 remaining
# 44:02 remaining
# 44:01 remaining
# 44:00 remaining
# 43:59 remaining
# 43:58 remaining
# 43:57 remaining
# 43:56 remaining
# 43:55 remaining
# 43:54 remaining
# 43:53 remaining
# 43:52 remaining
# 43:51 remaining
# 43:50 remaining
# 43:49 remaining
# 43:48 remaining
# 43:47 remaining
# 43:46 remaining
# 43:45 remaining
# 43:44 remaining
# 43:43 remaining
# 43:42 remaining
# 43:41 remaining
# 43:40 remaining
# 43:39 remaining
# 43:38 remaining
# 43:37 remaining
# 43:36 remaining
# 43:35 remaining
# 43:34 remaining
# 43:33 remaining
# 43:32 remaining
# 43:31 remaining
# 43:30 remaining
# 43:29 remaining
# 43:28 remaining
# 43:27 remaining
# 43:26 remaining
# 43:25 remaining
# 43:24 remaining
# 43:23 remaining
# 43:22 remaining
# 43:21 remaining
# 43:20 remaining
# 43:19 remaining
# 43:18 remaining
# 43:17 remaining
# 43:16 remaining
# 43:15 remaining
# 43:14 remaining
# 43:13 remaining
# 43:12 remaining
# 43:11 remaining
# 43:10 remaining
# 43:09 remaining
# 43:08 remaining
# 43:07 remaining
# 43:06 remaining
# 43:05 remaining
# 43:04 remaining
# 43:03 remaining
# 43:02 remaining
# 43:01 remaining
# 43:00 remaining
# 42:59 remaining
# 42:58 remaining
# 42:57 remaining
# 42:56 remaining
# 42:55 remaining
# 42:54 remaining
# 42:53 remaining
# 42:52 remaining
# 42:51 remaining
# 42:50 remaining
# 42:49 remaining
# 42:48 remaining
# 42:47 remaining
# 42:46 remaining
# 42:45 remaining
# 42:44 remaining
# 42:43 remaining
# 42:42 remaining
# 42:41 remaining
# 42:40 remaining
# 42:39 remaining
# 42:38 remaining
# 42:37 remaining
# 42:36 remaining
# 42:35 remaining
# 42:34 remaining
# 42:33 remaining
# 42:32 remaining
# 42:31 remaining
# 42:30 remaining
# 42:29 remaining
# 42:28 remaining
# 42:27 remaining
# 42:26 remaining
# 42:25 remaining
# 42:24 remaining
# 42:23 remaining
# 42:22 remaining
# 42:21 remaining
# 42:20 remaining
# 42:19 remaining
# 42:18 remaining
# 42:17 remaining
# 42:16 remaining
# 42:15 remaining
# 42:14 remaining
# 42:13 remaining
# 42:12 remaining
# 42:11 remaining
# 42:10 remaining
# 42:09 remaining
# 42:08 remaining
# 42:07 remaining
# 42:06 remaining
# 42:05 remaining
# 42:04 remaining
# 42:03 remaining
# 42:02 remaining
# 42:01 remaining
# 42:00 remaining
# 41:59 remaining
# 41:58 remaining
# 41:57 remaining
# 41:56 remaining
# 41:55 remaining
# 41:54 remaining
# 41:53 remaining
# 41:52 remaining
# 41:51 remaining
# 41:50 remaining
# 41:49 remaining
# 41:48 remaining
# 41:47 remaining
# 41:46 remaining
# 41:45 remaining
# 41:44 remaining
# 41:43 remaining
# 41:42 remaining
# 41:41 remaining
# 41:40 remaining
# 41:39 remaining
# 41:38 remaining
# 41:37 remaining
# 41:36 remaining
# 41:35 remaining
# 41:34 remaining
# 41:33 remaining
# 41:32 remaining
# 41:31 remaining
# 41:30 remaining
# 41:29 remaining
# 41:28 remaining
# 41:27 remaining
# 41:26 remaining
# 41:25 remaining
# 41:24 remaining
# 41:23 remaining
# 41:22 remaining
# 41:21 remaining
# 41:20 remaining
# 41:19 remaining
# 41:18 remaining
# 41:17 remaining
# 41:16 remaining
# 41:15 remaining
# 41:14 remaining
# 41:13 remaining
# 41:12 remaining
# 41:11 remaining
# 41:10 remaining
# 41:09 remaining
# 41:08 remaining
# 41:07 remaining
# 41:06 remaining
# 41:05 remaining
# 41:04 remaining
# 41:03 remaining
# 41:02 remaining
# 41:01 remaining
# 41:00 remaining
# 40:59 remaining
# 40:58 remaining
# 40:57 remaining
# 40:56 remaining
# 40:55 remaining
# 40:54 remaining
# 40:53 remaining
# 40:52 remaining
# 40:51 remaining
# 40:50 remaining
# 40:49 remaining
# 40:48 remaining
# 40:47 remaining
# 40:46 remaining
# 40:45 remaining
# 40:44 remaining
# 40:43 remaining
# 40:42 remaining
# 40:41 remaining
# 40:40 remaining
# 40:39 remaining
# 40:38 remaining
# 40:37 remaining
# 40:36 remaining
# 40:35 remaining
# 40:34 remaining
# 40:33 remaining
# 40:32 remaining
# 40:31 remaining
# 40:30 remaining
# 40:29 remaining
# 40:28 remaining
# 40:27 remaining
# 40:26 remaining
# 40:25 remaining
# 40:24 remaining
# 40:23 remaining
# 40:22 remaining
# 40:21 remaining
# 40:20 remaining
# 40:19 remaining
# 40:18 remaining
# 40:17 remaining
# 40:16 remaining
# 40:15 remaining
# 40:14 remaining
# 40:13 remaining
# 40:12 remaining
# 40:11 remaining
# 40:10 remaining
# 40:09 remaining
# 40:08 remaining
# 40:07 remaining
# 40:06 remaining
# 40:05 remaining
# 40:04 remaining
# 40:03 remaining
# 40:02 remaining
# 40:01 remaining
# 40:00 remaining
# 39:59 remaining
# 39:58 remaining
# 39:57 remaining
# 39:56 remaining
# 39:55 remaining
# 39:54 remaining
# 39:53 remaining
# 39:52 remaining
# 39:51 remaining
# 39:50 remaining
# 39:49 remaining
# 39:48 remaining
# 39:47 remaining
# 39:46 remaining
# 39:45 remaining
# 39:44 remaining
# 39:43 remaining
# 39:42 remaining
# 39:41 remaining
# 39:40 remaining
# 39:39 remaining
# 39:38 remaining
# 39:37 remaining
# 39:36 remaining
# 39:35 remaining
# 39:34 remaining
# 39:33 remaining
# 39:32 remaining
# 39:31 remaining
# 39:30 remaining
# 39:29 remaining
# 39:28 remaining
# 39:27 remaining
# 39:26 remaining
# 39:25 remaining
# 39:24 remaining
# 39:23 remaining
# 39:22 remaining
# 39:21 remaining
# 39:20 remaining
# 39:19 remaining
# 39:18 remaining
# 39:17 remaining
# 39:16 remaining
# 39:15 remaining
# 39:14 remaining
# 39:13 remaining
# 39:12 remaining
# 39:11 remaining
# 39:10 remaining
# 39:09 remaining
# 39:08 remaining
# 39:07 remaining
# 39:06 remaining
# 39:05 remaining
# 39:04 remaining
# 39:03 remaining
# 39:02 remaining
# 39:01 remaining
# 39:00 remaining
# 38:59 remaining
# 38:58 remaining
# 38:57 remaining
# 38:56 remaining
# 38:55 remaining
# 38:54 remaining
# 38:53 remaining
# 38:52 remaining
# 38:51 remaining
# 38:50 remaining
# 38:49 remaining
# 38:48 remaining
# 38:47 remaining
# 38:46 remaining
# 38:45 remaining
# 38:44 remaining
# 38:43 remaining
# 38:42 remaining
# 38:41 remaining
# 38:40 remaining
# 38:39 remaining
# 38:38 remaining
# 38:37 remaining
# 38:36 remaining
# 38:35 remaining
# 38:34 remaining
# 38:33 remaining
# 38:32 remaining
# 38:31 remaining
# 38:30 remaining
# 38:29 remaining
# 38:28 remaining
# 38:27 remaining
# 38:26 remaining
# 38:25 remaining
# 38:24 remaining
# 38:23 remaining
# 38:22 remaining
# 38:21 remaining
# 38:20 remaining
# 38:19 remaining
# 38:18 remaining
# 38:17 remaining
# 38:16 remaining
# 38:15 remaining
# 38:14 remaining
# 38:13 remaining
# 38:12 remaining
# 38:11 remaining
# 38:10 remaining
# 38:09 remaining
# 38:08 remaining
# 38:07 remaining
# 38:06 remaining
# 38:05 remaining
# 38:04 remaining
# 38:03 remaining
# 38:02 remaining
# 38:01 remaining
# 38:00 remaining
# 37:59 remaining
# 37:58 remaining
# 37:57 remaining
# 37:56 remaining
# 37:55 remaining
# 37:54 remaining
# 37:53 remaining
# 37:52 remaining
# 37:51 remaining
# 37:50 remaining
# 37:49 remaining
# 37:48 remaining
# 37:47 remaining
# 37:46 remaining
# 37:45 remaining
# 37:44 remaining
# 37:43 remaining
# 37:42 remaining
# 37:41 remaining
# 37:40 remaining
# 37:39 remaining
# 37:38 remaining
# 37:37 remaining
# 37:36 remaining
# 37:35 remaining
# 37:34 remaining
# 37:33 remaining
# 37:32 remaining
# 37:31 remaining
# 37:30 remaining
# 37:29 remaining
# 37:28 remaining
# 37:27 remaining
# 37:26 remaining
# 37:25 remaining
# 37:24 remaining
# 37:23 remaining
# 37:22 remaining
# 37:21 remaining
# 37:20 remaining
# 37:19 remaining
# 37:18 remaining
# 37:17 remaining
# 37:16 remaining
# 37:15 remaining
# 37:14 remaining
# 37:13 remaining
# 37:12 remaining
# 37:11 remaining
# 37:10 remaining
# 37:09 remaining
# 37:08 remaining
# 37:07 remaining
# 37:06 remaining
# 37:05 remaining
# 37:04 remaining
# 37:03 remaining
# 37:02 remaining
# 37:01 remaining
# 37:00 remaining
# 36:59 remaining
# 36:58 remaining
# 36:57 remaining
# 36:56 remaining
# 36:55 remaining
# 36:54 remaining
# 36:53 remaining
# 36:52 remaining
# 36:51 remaining
# 36:50 remaining
# 36:49 remaining
# 36:48 remaining
# 36:47 remaining
# 36:46 remaining
# 36:45 remaining
# 36:44 remaining
# 36:43 remaining
# 36:42 remaining
# 36:41 remaining
# 36:40 remaining
# 36:39 remaining
# 36:38 remaining
# 36:37 remaining
# 36:36 remaining
# 36:35 remaining
# 36:34 remaining
# 36:33 remaining
# 36:32 remaining
# 36:31 remaining
# 36:30 remaining
# 36:29 remaining
# 36:28 remaining
# 36:27 remaining
# 36:26 remaining
# 36:25 remaining
# 36:24 remaining
# 36:23 remaining
# 36:22 remaining
# 36:21 remaining
# 36:20 remaining
# 36:19 remaining
# 36:18 remaining
# 36:17 remaining
# 36:16 remaining
# 36:15 remaining
# 36:14 remaining
# 36:13 remaining
# 36:12 remaining
# 36:11 remaining
# 36:10 remaining
# 36:09 remaining
# 36:08 remaining
# 36:07 remaining
# 36:06 remaining
# 36:05 remaining
# 36:04 remaining
# 36:03 remaining
# 36:02 remaining
# 36:01 remaining
# 36:00 remaining
# 35:59 remaining
# 35:58 remaining
# 35:57 remaining
# 35:56 remaining
# 35:55 remaining
# 35:54 remaining
# 35:53 remaining
# 35:52 remaining
# 35:51 remaining
# 35:50 remaining
# 35:49 remaining
# 35:48 remaining
# 35:47 remaining
# 35:46 remaining
# 35:45 remaining
# 35:44 remaining
# 35:43 remaining
# 35:42 remaining
# 35:41 remaining
# 35:40 remaining
# 35:39 remaining
# 35:38 remaining
# 35:37 remaining
# 35:36 remaining
# 35:35 remaining
# 35:34 remaining
# 35:33 remaining
# 35:32 remaining
# 35:31 remaining
# 35:30 remaining
# 35:29 remaining
# 35:28 remaining
# 35:27 remaining
# 35:26 remaining
# 35:25 remaining
# 35:24 remaining
# 35:23 remaining
# 35:22 remaining
# 35:21 remaining
# 35:20 remaining
# 35:19 remaining
# 35:18 remaining
# 35:17 remaining
# 35:16 remaining
# 35:15 remaining
# 35:14 remaining
# 35:13 remaining
# 35:12 remaining
# 35:11 remaining
# 35:10 remaining
# 35:09 remaining
# 35:08 remaining
# 35:07 remaining
# 35:06 remaining
# 35:05 remaining
# 35:04 remaining
# 35:03 remaining
# 35:02 remaining
# 35:01 remaining
# 35:00 remaining
# 34:59 remaining
# 34:58 remaining
# 34:57 remaining
# 34:56 remaining
# 34:55 remaining
# 34:54 remaining
# 34:53 remaining
# 34:52 remaining
# 34:51 remaining
# 34:50 remaining
# 34:49 remaining
# 34:48 remaining
# 34:47 remaining
# 34:46 remaining
# 34:45 remaining
# 34:44 remaining
# 34:43 remaining
# 34:42 remaining
# 34:41 remaining
# 34:40 remaining
# 34:39 remaining
# 34:38 remaining
# 34:37 remaining
# 34:36 remaining
# 34:35 remaining
# 34:34 remaining
# 34:33 remaining
# 34:32 remaining
# 34:31 remaining
# 34:30 remaining
# 34:29 remaining
# 34:28 remaining
# 34:27 remaining
# 34:26 remaining
# 34:25 remaining
# 34:24 remaining
# 34:23 remaining
# 34:22 remaining
# 34:21 remaining
# 34:20 remaining
# 34:19 remaining
# 34:18 remaining
# 34:17 remaining
# 34:16 remaining
# 34:15 remaining
# 34:14 remaining
# 34:13 remaining
# 34:12 remaining
# 34:11 remaining
# 34:10 remaining
# 34:09 remaining
# 34:08 remaining
# 34:07 remaining
# 34:06 remaining
# 34:05 remaining
# 34:04 remaining
# 34:03 remaining
# 34:02 remaining
# 34:01 remaining
# 34:00 remaining
# 33:59 remaining
# 33:58 remaining
# 33:57 remaining
# 33:56 remaining
# 33:55 remaining
# 33:54 remaining
# 33:53 remaining
# 33:52 remaining
# 33:51 remaining
# 33:50 remaining
# 33:49 remaining
# 33:48 remaining
# 33:47 remaining
# 33:46 remaining
# 33:45 remaining
# 33:44 remaining
# 33:43 remaining
# 33:42 remaining
# 33:41 remaining
# 33:40 remaining

# %% [markdown]
# <a id='module-1'></a>
# # **Module 1: Introduction to Statistics & Data Exploration**
#
# ### What is Statistics?
# Statistics is the science of collecting, analyzing, interpreting, presenting, and organizing data. It helps us make sense of data and draw conclusions.
#
# ### Descriptive vs Inferential Statistics
# - **Descriptive Statistics** summarize and describe the features of a dataset (mean, median, etc.).
# - **Inferential Statistics** use sample data to make inferences or predictions about a population.
#
# ### Types of Data
# - **Numerical (Quantitative):** Numbers (e.g., height, salary)
# - **Categorical (Qualitative):** Categories/labels (e.g., gender, color)
# - **Ordinal:** Categorical data with an order (e.g., rankings)
#
# ### Measures of Central Tendency
# - **Mean:** Average value
# - **Median:** Middle value
# - **Mode:** Most frequent value
#
# ### Measures of Variability
# - **Range:** Difference between max and min
# - **Variance:** Average squared deviation from mean
# - **Standard Deviation:** Square root of variance; measures spread
#
# Let's explore these concepts with Python!

# %%
# Import packages
import numpy as np
import pandas as pd

# Sample dataset
data = {'Age': [23, 45, 12, 36, 28, 52, 33, 41, 25, 39],
        'Salary': [50000, 80000, 12000, 67000, 56000, 90000, 59000, 76000, 51000, 73000],
        'Department': ['HR', 'Engineering', 'Sales', 'Engineering', 'HR', 'Management', 'Sales', 'Engineering', 'HR', 'Management']}

df = pd.DataFrame(data)
df
# Out:
#    Age  Salary   Department
# 0   23   50000           HR
# 1   45   80000  Engineering
# 2   12   12000        Sales
# 3   36   67000  Engineering
# 4   28   56000           HR
# 5   52   90000   Management
# 6   33   59000        Sales
# 7   41   76000  Engineering
# 8   25   51000           HR
# 9   39   73000   Management

# %% [markdown]
# ### Central Tendency in Practice

# %%
print('Mean Age:', df['Age'].mean())
print('Median Age:', df['Age'].median())
print('Mode Age:', df['Age'].mode()[0])
# Out:
# Mean Age: 33.4
# Median Age: 34.5
# Mode Age: 12

# %% [markdown]
# ### Variability in Practice

# %%
print('Range of Salary:', df['Salary'].max() - df['Salary'].min())
print('Variance of Salary:', df['Salary'].var())
print('Standard Deviation of Salary:', df['Salary'].std())
# Out:
# Range of Salary: 78000
# Variance of Salary: 472933333.3333333
# Standard Deviation of Salary: 21747.03044862294

# %% [markdown]
# ### Data Exploration
# Let's check some basic info and summary statistics.

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         10 non-null     int64
#  1   Salary      10 non-null     int64
#  2   Department  10 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes
#              Age        Salary
# count  10.000000     10.000000
# mean   33.400000  61400.000000
# std    11.749232  21747.030449
# min    12.000000  12000.000000
# 25%    25.750000  52250.000000
# 50%    34.500000  63000.000000
# 75%    40.500000  75250.000000
# max    52.000000  90000.000000

# %% [markdown]
# #### Exercises
# 1. Calculate the mean and median salary for each department. (Store in `mean_salary_by_dept` and `median_salary_by_dept`)
# 2. What is the mode of the 'Department' column? (Store in `department_mode`)
# 3. Find the standard deviation of ages for the HR department. (Store in `std_age_hr`)

# %%
df.head()
# Out:
#    Age  Salary   Department
# 0   23   50000           HR
# 1   45   80000  Engineering
# 2   12   12000        Sales
# 3   36   67000  Engineering
# 4   28   56000           HR

# %%
# STUDENT: Write your answers below using the specified variable names.

mean_salary_by_dept = df.groupby('Department')['Salary'].mean()
median_salary_by_dept = df.groupby('Department')['Salary'].median()
department_mode = df['Department'].mode()[0]
std_age_hr = df[df['Department'] == 'HR']['Age'].std()

# %% [markdown]
# #### Validate Your Module 1 Solutions
# Run the cell below to check your answers for Module 1. The feedback and your score will be displayed.

# %%
try:
    from statstest import test
    test.test_module1(df, {
    'mean_salary_by_dept': mean_salary_by_dept,
    'median_salary_by_dept': median_salary_by_dept,
    'department_mode': department_mode,
    'std_age_hr': std_age_hr
})
except:
    print("Try Again!")
# Out:
# Module 1 Score: 4/4
# Q1: Mean salary by department correct.
# Q2: Median salary by department correct.
# Q3: Department mode correct.
# Q4: Standard deviation of age in HR correct.

# %% [markdown]
# ---
# <a id='module-2'></a>
# # **Module 2: Data Visualization & Distributions**
#
# ### Why Visualize Data?
# Visualization helps us understand patterns, trends, and outliers in data. It makes complex information accessible and actionable.
#
# ### Common Plots
# - **Histogram:** Distribution of numeric data
# - **Boxplot:** Shows distribution, median, quartiles, and outliers
# - **Scatterplot:** Relationship between two numeric variables
#
# ### Understanding Distributions
# - **Normal Distribution:** Bell-shaped, symmetric
# - **Skewed Distribution:** Data leans left or right
#
# Let's visualize!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# Histogram of Age
plt.figure(figsize=(6,4))
sns.histplot(df['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# Boxplot of Salary by Department
plt.figure(figsize=(6,4))
sns.boxplot(x='Department', y='Salary', data=df)
plt.title('Salary Distribution by Department')
plt.show()

# Scatterplot Age vs Salary
plt.figure(figsize=(6,4))
sns.scatterplot(x='Age', y='Salary', data=df, hue='Department')
plt.title('Age vs Salary')
plt.show()

# %% [markdown]
# #### Exercises
# 1. Plot a histogram for Salaries. (Store your matplotlib Figure in `salary_hist_fig`)
# 2. Create a boxplot for Age by Department. (Store your matplotlib Figure in `age_box_fig`)
# 3. In a variable `has_outliers`, set to True if you observe any outliers in the boxplot, else False.

# %%
# STUDENT: Write your answers below

salary_hist_fig = plt.figure(figsize=(6,4))
sns.histplot(df['Salary'], kde=True)
plt.title('Salary Distribution')

age_box_fig = plt.figure(figsize=(6,4))
sns.boxplot(x='Department', y='Age', data=df)
plt.title('Age by Department')

has_outliers = True

# %% [markdown]
# #### Validate Your Module 2 Solutions
# Run the cell below to check your answers for Module 2. The feedback and your score will be displayed.

# %%
try:
    from statstest import test
    test.test_module2(df, {
    'salary_hist_fig': salary_hist_fig,
    'age_box_fig': age_box_fig,
    'has_outliers': has_outliers
})
except:
    print("Try Again!")
# Out:
# Module 2 Score: 3/3
# Q1: Salary histogram figure present.
# Q2: Age boxplot figure present.
# Q3: Outlier detection variable present.

# %% [markdown]
# ---
# <a id='module-3'></a>
# # **Module 3: Probability & Sampling**
#
# ### What is Probability?
# Probability measures the likelihood of an event occurring, between 0 (impossible) and 1 (certain).
#
# ### Probability Distributions
# - **Normal Distribution:** Most data falls near the mean
# - **Binomial Distribution:** Number of successes in fixed trials (e.g., coin toss)
# - **Uniform Distribution:** All outcomes equally likely
#
# ### Sampling
# - **Random Sampling:** Every data point has equal chance
# - **Stratified Sampling:** Data divided into subgroups, samples taken from each
#
# ### Central Limit Theorem (CLT)
# CLT states that the sampling distribution of the sample mean approaches a normal distribution, as the sample size increases, regardless of the original distribution.
#
# Let's simulate some probabilities!

# %%
from scipy.stats import norm, binom

# Normal Distribution
mu, sigma = 0, 1
data_norm = np.random.normal(mu, sigma, 1000)
plt.figure(figsize=(6,4))
sns.histplot(data_norm, kde=True)
plt.title('Simulated Normal Distribution')
plt.show()

# Binomial Distribution (e.g. 10 coin tosses, p=0.5)
n, p = 10, 0.5
data_binom = binom.rvs(n, p, size=1000)
plt.figure(figsize=(6,4))
sns.histplot(data_binom, kde=False, bins=n+1)
plt.title('Simulated Binomial Distribution (10 coin tosses)')
plt.show()

# Central Limit Theorem: mean of random samples
means = [np.mean(np.random.choice(data_norm, 30)) for _ in range(1000)]
plt.figure(figsize=(6,4))
sns.histplot(means, kde=True)
plt.title('Means of 1000 samples of size 30 (CLT)')
plt.show()

# %% [markdown]
# #### Exercises
# 1. Simulate and plot a uniform distribution of 1000 values in [0,1]. (Store the array as `uniform_data` and the figure as `uniform_fig`)
# 2. Try changing the parameters of the binomial distribution (n, p). What do you observe? (Store a short answer string in `binom_observation`)
# 3. In a variable `clt_reason`, explain briefly why the CLT matters in machine learning (as a string).

# %%
# STUDENT: Write your answers below

uniform_data = np.random.uniform(0, 1, 1000)

uniform_fig = plt.figure(figsize=(6,4))
sns.histplot(uniform_data, kde=True)
plt.title('Uniform Distribution')

binom_observation = "Increasing n makes the binomial distribution more symmetric and bell-shaped; changing p skews the distribution left or right."

clt_reason = "The CLT ensures that sample means are normally distributed, allowing reliable inference and confidence intervals in machine learning even if the data is not normal."

# %% [markdown]
# #### Validate Your Module 3 Solutions
# Run the cell below to check your answers for Module 3. The feedback and your score will be displayed.

# %%
try:
    from statstest import test
    test.test_module3(df, {
    'uniform_data': uniform_data,
    'uniform_fig': uniform_fig,
    'binom_observation': binom_observation,
    'clt_reason': clt_reason
})
except:
    print("Try Again!")
# Out:
# Module 3 Score: 4/4
# Q1: Uniform distribution simulation correct.
# Q2: Uniform distribution figure present.
# Q3: Binomial observation answer present.
# Q4: CLT reason answer present.

# %% [markdown]
# ---
# <a id='module-4'></a>
# # **Module 4: Hypothesis Testing & Statistical Inference**
#
# ### What is Hypothesis Testing?
# A method to decide whether there is enough evidence to reject a hypothesis about a population.
#
# ### Steps in Hypothesis Testing
# 1. State the null (H0) and alternative (H1) hypotheses
# 2. Choose a significance level (alpha, e.g., 0.05)
# 3. Calculate a test statistic
# 4. Find the p-value
# 5. Reject or fail to reject H0
#
# ### Common Tests
# - **t-test:** Compare means of two groups
# - **Chi-square test:** Compare categorical variables
# - **ANOVA:** Compare means of more than two groups
#
# Let's practice with Python!

# %%
from scipy import stats

# Example: Is the mean salary in Engineering different from HR?
eng_salary = df[df['Department'] == 'Engineering']['Salary']
hr_salary = df[df['Department'] == 'HR']['Salary']

t_stat, p_val = stats.ttest_ind(eng_salary, hr_salary)
print('t-statistic:', t_stat)
print('p-value:', p_val)
if p_val < 0.05:
    print('Reject the null hypothesis (means are different)')
else:
    print('Fail to reject the null hypothesis (means are similar)')
# Out:
# t-statistic: 5.153734142323998
# p-value: 0.006727071309846925
# Reject the null hypothesis (means are different)

# %% [markdown]
# #### Exercises
# 1. Test if the mean age is different between Management and Sales departments (store p-value as `p_age_mgmt_sales` and True/False in `age_diff_significant` for p<0.05).
# 2. What does it mean if the p-value is less than 0.05? (Store in `pval_meaning` string)
# 3. Try a chi-square test for the relationship between Department and whether Salary > 60000. Store the p-value as `p_chi2`.

# %%
# STUDENT: Write your answers below

mgmt_age = df[df['Department'] == 'Management']['Age']
sales_age = df[df['Department'] == 'Sales']['Age']

p_age_mgmt_sales = stats.ttest_ind(mgmt_age, sales_age).pvalue

age_diff_significant = p_age_mgmt_sales < 0.05

pval_meaning = "If the p-value is less than 0.05, it means there is strong evidence to reject the null hypothesis, indicating a statistically significant difference."

df['Salary_Above_60k'] = df['Salary'] > 60000
cross_table = pd.crosstab(df['Department'], df['Salary_Above_60k'])
p_chi2 = stats.chi2_contingency(cross_table).pvalue

# %% [markdown]
# #### Validate Your Module 4 Solutions
# Run the cell below to check your answers for Module 4. The feedback and your score will be displayed.

# %%
try:
    from statstest import test
    test.test_module4(df, {
    'p_age_mgmt_sales': p_age_mgmt_sales,
    'age_diff_significant': age_diff_significant,
    'pval_meaning': pval_meaning,
    'p_chi2': p_chi2
})
except:
    print("Try Again!")
# Out:
# Module 4 Score: 4/4
# Q1: p-value for age difference present and valid.
# Q2: Significance variable present.
# Q3: p-value meaning answer present and mentions 'reject'.
# Q4: Chi-square p-value present and valid.

# %% [markdown]
# ---
# <a id='module-5'></a>
# # **Module 5: Correlation, Regression & Feature Relationships**
#
# ### Correlation
# Correlation measures how two variables move together.
# - **Pearson correlation:** Linear relationship (-1 to +1)
# - **Spearman correlation:** Monotonic relationship (not necessarily linear)
#
# ### Linear Regression
# A method to model the relationship between a dependent variable and one or more independent variables.
#
# - **Simple Linear Regression:** One input, one output
# - **Overfitting/Underfitting:** Too complex/simple models can hurt predictions
#
# Let's try them in Python!

# %%
# Correlation
corr = df[['Age', 'Salary']].corr()
print('Correlation matrix:\n', corr)

# Simple Linear Regression: Predict Salary from Age
from sklearn.linear_model import LinearRegression

X = df[['Age']]
y = df['Salary']
model = LinearRegression()
model.fit(X, y)

print('Regression Coefficient (slope):', model.coef_[0])
print('Intercept:', model.intercept_)

# Plot the regression
plt.figure(figsize=(6,4))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.plot(df['Age'], model.predict(X), color='red')
plt.title('Linear Regression: Salary vs Age')
plt.show()
# Out:
# Correlation matrix:
#               Age    Salary
# Age     1.000000  0.970343
# Salary  0.970343  1.000000
# Regression Coefficient (slope): 1796.0399227302007
# Intercept: 1412.2665808113015

# %% [markdown]
# #### Exercises
# 1. Calculate the Spearman correlation between Age and Salary (store as `spearman_corr`).
# 2. Fit a regression model to predict Salary from both Age and a dummy variable for Department. Store the regression coefficients (as a list) in `regression_coefs`.
# 3. What does a negative correlation mean in this context? (Store in `neg_corr_meaning` as a string).

# %%
# STUDENT: Write your answers below

spearman_corr = df[['Age', 'Salary']].corr(method='spearman').iloc[0,1]

X = pd.get_dummies(df[['Age', 'Department']], drop_first=True)
y = df['Salary']
lr = LinearRegression()
lr.fit(X, y)
regression_coefs = lr.coef_

neg_corr_meaning = 'A negative correlation means that as one variable increases, the other tends to decrease. In this context, it would imply that higher Age is associated with lower Salary, or vice versa.'

# %% [markdown]
# #### Validate Your Module 5 Solutions
# Run the cell below to check your answers for Module 5. The feedback and your score will be displayed.

# %%
try:
    from statstest import test
    test.test_module5(df, {
    'spearman_corr': spearman_corr,
    'regression_coefs': regression_coefs,
    'neg_corr_meaning': neg_corr_meaning
})
except:
    print("Try Again!")
# Out:
# Module 5 Score: 3/3
# Q1: Spearman correlation present and valid.
# Q2: Regression coefficients present and valid.
# Q3: Negative correlation meaning answer present and mentions 'decrease'.

# %% [markdown]
# ---
# ## Final Score and Feedback
# After completing all modules and their validations, run the cell below to get your detailed feedback and final score!

# %%
from statstest import feedback
feedback.show_final_feedback()
# Out:
# ======== DETAILED FEEDBACK ========
# Module 1 Feedback:
#    Q1: Mean salary by department correct.
#    Q2: Median salary by department correct.
#    Q3: Department mode correct.
#    Q4: Standard deviation of age in HR correct.
#
# Module 2 Feedback:
#    Q1: Salary histogram figure present.
#    Q2: Age boxplot figure present.
#    Q3: Outlier detection variable present.
#
# Module 3 Feedback:
#    Q1: Uniform distribution simulation correct.
#    Q2: Uniform distribution figure present.
#    Q3: Binomial observation answer present.
#    Q4: CLT reason answer present.
#
# Module 4 Feedback:
#    Q1: p-value for age difference present and valid.
#    Q2: Significance variable present.
#    Q3: p-value meaning answer present and mentions 'reject'.
#    Q4: Chi-square p-value present and valid.
#
# Module 5 Feedback:
#    Q1: Spearman correlation present and valid.
#    Q2: Regression coefficients present and valid.
#    Q3: Negative correlation meaning answer present and mentions 'decrease'.
#
# FINAL SCORE: 18/18
# Excellent work! All answers are correct.
